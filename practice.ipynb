# %%
directories = ['Documents', 'Music', 'Desktop', 'Downloads', 'Pictures', 'Movies']
for directory in directories:
    print(directory)
# Out:
# Documents
# Music
# Desktop
# Downloads
# Pictures
# Movies

# %%
import os
for item in os.listdir('sample_data'):
    if os.path.isdir(item):
        print("This is a directory: {0}".format(item))
    else:
        print("This is a directory:  {0}".format(item))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import os
# ----> 2 for item in os.listdir('sample_data'):
#       3     if os.path.isdir(item):
#       4         print("This is a directory: {0}".format(item))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample_data'

# %%
important_directories = []
for item in os.listdir('.'):
    if os.path.isdir(item):
        important_directories.append(item)
    print(important_directories)
# Out:
# []
# []
# []
# []
# []
# ['.ipynb_checkpoints']
# ['.ipynb_checkpoints', 'venv']
# ['.ipynb_checkpoints', 'venv', '.git']
# ['.ipynb_checkpoints', 'venv', '.git', 'file-size-report']

# %%
items = ['first', 'second', 'third', 'foo']
items[-1]
url = "https://colab.research.com/drive/asdfjhasdf/alfredo/oreilly"

parts = url.split('/')
