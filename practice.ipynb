# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading faker-40.1.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tzdata in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from faker) (2025.2)
# Downloading faker-40.1.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 31.3 MB/s  0:00:00
# Installing collected packages: faker
# Successfully installed faker-40.1.0

# %%
from faker import Faker

fake = Faker()

print(fake.name())
print(fake.email())
print(fake.address())
# Out:
# Mathew Gomez
# donnasutton@example.org
# 71749 David Stream
# Davidbury, PA 76506

# %%
import sqlite3
from faker import Faker
import random

fake = Faker()

conn = sqlite3.connect("practice.db")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS users (
    id INTEGER PRIMARY KEY,
    name TEXT,
    email TEXT,
    age INTEGER
)
""")

for _ in range(20):
    cursor.execute("""
        INSERT INTO users (name, email, age)
        VALUES (?, ?, ?)
    """, (
        fake.name(),
        fake.email(),
        random.randint(18, 70)
    ))

conn.commit()

# %%
cursor.execute("SELECT * FROM users LIMIT 5")
cursor.fetchall()
# Out:
# [(1, 'Dan Brown', 'emilyosborne@example.org', 70),
#  (2, 'Charles Buchanan', 'ericadkins@example.org', 35),
#  (3, 'Keith Tucker', 'michael21@example.net', 40),
#  (4, 'David Terry', 'cgreen@example.net', 51),
#  (5, 'Carol Mendez', 'maryjones@example.net', 26)]

# %%
cursor.execute("SELECT name, age FROM users WHERE age > 40")
cursor.fetchall()
# Out:
# [('Dan Brown', 70),
#  ('David Terry', 51),
#  ('Matthew Myers', 44),
#  ('Erin Hall', 54),
#  ('Daniel Hall', 60),
#  ('Timothy Moore', 66),
#  ('Robert Cooper', 60),
#  ('Jessica Perry', 44),
#  ('Jessica Miles', 65),
#  ('Shane Hutchinson', 53),
#  ('Trevor Ramos', 55),
#  ('Terri Manning DDS', 61),
#  ('Raymond White', 65),
#  ('Dr. Katrina Graves', 62),
#  ('David Morrow', 52),
#  ('Katie Jackson', 49),
#  ('Matthew Callahan', 46),
#  ('Alexandria Long', 62)]

# %%
cursor.execute("SELECT COUNT(*) FROM users")
cursor.fetchone()
# Out:
# (40,)

# %%
import os
for root, directories, files in os.walk('.'):
    for file in files:
        print(f" File found: {file}")
# Out:
#  File found: .DS_Store
#  File found: .localized
#  File found: Untitled.ipynb
#  File found: practice.ipynb
#  File found: practice.db
#  File found: Screenshot 2025-05-22 at 1.23.32 PM-checkpoint.png
#  File found: Screenshot 2025-09-11 at 10.39.24 AM-checkpoint.png
#  File found: Screenshot 2025-06-16 at 2.47.30 PM-checkpoint.png
#  File found: Screenshot 2025-12-13 at 11.56.41 AM-checkpoint.png
#  File found: Screenshot 2025-06-16 at 2.47.25 PM-checkpoint.png
#  File found: Screenshot 2025-06-14 at 2.56.25 PM-checkpoint.png
#  File found: Untitled-checkpoint.ipynb
#  File found: practice-checkpoint.ipynb

# %%
for root, directories, files in os.walk('.'):
    for  file in files:
        full_path = os.path.join(root, file)
        print ( f"File found: {full_path}")
# Out:
# File found: ./.DS_Store
# File found: ./.localized
# File found: ./Untitled.ipynb
# File found: ./practice.ipynb
# File found: ./practice.db
# File found: ./.ipynb_checkpoints/Screenshot 2025-05-22 at 1.23.32 PM-checkpoint.png
# File found: ./.ipynb_checkpoints/Screenshot 2025-09-11 at 10.39.24 AM-checkpoint.png
# File found: ./.ipynb_checkpoints/Screenshot 2025-06-16 at 2.47.30 PM-checkpoint.png
# File found: ./.ipynb_checkpoints/Screenshot 2025-12-13 at 11.56.41 AM-checkpoint.png
# File found: ./.ipynb_checkpoints/Screenshot 2025-06-16 at 2.47.25 PM-checkpoint.png
# File found: ./.ipynb_checkpoints/Screenshot 2025-06-14 at 2.56.25 PM-checkpoint.png
# File found: ./.ipynb_checkpoints/Untitled-checkpoint.ipynb
# File found: ./.ipynb_checkpoints/practice-checkpoint.ipynb
